# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import counting_fns as cf
## Logistic Regression
# Months
months = ['June', 'July', 'August', 'September', 'October']

# Set the path to the csv files
data_path = '/Users/mau/Library/CloudStorage/Dropbox/Mac/Documents/Dissertation/Chapter 2/Entire_Data/Feauture Importance/Minutes/SVM/'

times = ["1min", "5min", "10min", "15min"]

# Create a list of dataframes
datasets = {}

# Read the csv files and append them to the list
for month in months:
    for time in times:
        name = month + '_' + time
        data = pd.read_csv(data_path + month + '/coefficients_df_' + time + '.csv')
        datasets[name] = data  

# Let's concact all 1min dataframes 
df_1min = pd.concat([datasets['June_1min'], datasets['July_1min'], datasets['August_1min'], datasets['September_1min'], datasets['October_1min']])

# Let's concact all 5min dataframes
df_5min = pd.concat([datasets['June_5min'], datasets['July_5min'], datasets['August_5min'], datasets['September_5min'], datasets['October_5min']])

# Let's concact all 10min dataframes
df_10min = pd.concat([datasets['June_10min'], datasets['July_10min'], datasets['August_10min'], datasets['September_10min'], datasets['October_10min']])

# Let's concact all 15min dataframes
df_15min = pd.concat([datasets['June_15min'], datasets['July_15min'], datasets['August_15min'], datasets['September_15min'], datasets['October_15min']])

# Drop the first column 
df_1min = df_1min.drop(df_1min.columns[0], axis=1)
df_5min = df_5min.drop(df_5min.columns[0], axis=1)
df_10min = df_10min.drop(df_10min.columns[0], axis=1)
df_15min = df_15min.drop(df_15min.columns[0], axis=1)

# %%
## Gruop dataframe to only show top 10 features
output_1min = cf.process_dataframe(df_1min, 'Feature', 'Coefficient', top_n=10)
output_5min = cf.process_dataframe(df_5min, 'Feature', 'Coefficient', top_n=10)
output_10min = cf.process_dataframe(df_10min, 'Feature', 'Coefficient', top_n=10)
output_15min = cf.process_dataframe(df_15min, 'Feature', 'Coefficient', top_n=10)

# Delete 'encoder__' from the feature names
output_1min['Feature'] = output_1min['Feature'].str.replace('encoder__age_gen_', '')
output_5min['Feature'] = output_5min['Feature'].str.replace('encoder__age_gen_', '')
output_10min['Feature'] = output_10min['Feature'].str.replace('encoder__age_gen_', '')
output_15min['Feature'] = output_15min['Feature'].str.replace('encoder__age_gen_', '')

# %%
# Plot 1 minute results
cf.plot_output_intervals(output_1min, '1 Minute', 45)

# %%
# Plot 5 minute results
cf.plot_output_intervals(output_5min, '5 Minutes', 45)

# %%
# Plot 10 minute results
cf.plot_output_intervals(output_10min, '10 Minutes', 45)

# %%
# Plot 15 minute results
cf.plot_output_intervals(output_15min, '15 Minutes', 45)

# %%
# Print the results
print('1 Minute')
print(output_1min)

print('5 Minutes')
print(output_5min)

print('10 Minutes')
print(output_10min)

print('15 Minutes')
print(output_15min)
# Out:
# 1 Minute
#              Feature      mean       std  abs_mean
# 65     max_slotdenom -0.645330  0.495553  0.645330
# 31             Gen Z -0.587518  0.066384  0.587518
# 70  min_theo_payback  0.461365  0.218979  0.461365
# 69     min_slotdenom  0.458704  0.290608  0.458704
# 33            Silent  0.346396  0.022752  0.346396
# 22  ave_theo_payback -0.269182  0.534058  0.269182
# 29      Baby Boomers  0.268547  0.009727  0.268547
# 32        Millenials -0.255068  0.028588  0.255068
# 25      ave_wageramt -0.220681  0.072740  0.220681
# 74           std_p/b -0.176605  0.045263  0.176605
# 5 Minutes
#                  Feature      mean       std  abs_mean
# 31                 Gen Z -0.522477  0.078768  0.522477
# 33                Silent  0.325370  0.037039  0.325370
# 32            Millenials -0.242615  0.028424  0.242615
# 29          Baby Boomers  0.231292  0.008771  0.231292
# 70      min_theo_payback  0.198380  0.065351  0.198380
# 23   ave_time_per_gamble -0.141676  0.016203  0.141676
# 24  ave_time_per_machine  0.113965  0.014179  0.113965
# 67   max_time_per_gamble  0.112148  0.010497  0.112148
# 30                 Gen X  0.095242  0.013888  0.095242
# 4                     #L  0.084303  0.010710  0.084303
# 10 Minutes
#                  Feature      mean       std  abs_mean
# 31                 Gen Z -0.463351  0.092434  0.463351
# 33                Silent  0.301935  0.035587  0.301935
# 22      ave_theo_payback  0.263948  0.106363  0.263948
# 32            Millenials -0.228651  0.028189  0.228651
# 29          Baby Boomers  0.211580  0.013349  0.211580
# 23   ave_time_per_gamble -0.194222  0.009258  0.194222
# 21         ave_slotdenom -0.160618  0.054493  0.160618
# 67   max_time_per_gamble  0.124785  0.005888  0.124785
# 24  ave_time_per_machine  0.120287  0.004569  0.120287
# 69         min_slotdenom  0.115393  0.042497  0.115393
# 15 Minutes
#                 Feature      mean       std  abs_mean
# 31                Gen Z -0.448733  0.075957  0.448733
# 33               Silent  0.287422  0.021390  0.287422
# 32           Millenials -0.218939  0.029433  0.218939
# 29         Baby Boomers  0.190545  0.012898  0.190545
# 23  ave_time_per_gamble -0.178978  0.010368  0.178978
# 22     ave_theo_payback  0.134661  0.049369  0.134661
# 25         ave_wageramt  0.131634  0.059585  0.131634
# 67  max_time_per_gamble  0.117755  0.009020  0.117755
# 76         std_wageramt -0.109202  0.037794  0.109202
# 77        total_gambles  0.108456  0.003373  0.108456
