# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Data Preprocessing

# %%
# Importing the libraries
import counting_fns as cf
import os
import pandas as pd


# List of all the months
months = ['2_June', '3_July', '4_August', '5_September', '6_October']

# Define the path to the data directory and columns to keep
data_path = "/Users/mau/Library/CloudStorage/Dropbox/Mac/Documents/Dissertation/Chapter 2/Entire_Data/By month"

# %%
# Best Hyperparameters: {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# Best Hyperparameters: {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Hyperparameters: {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# {'C': 10, 'max_iter': 300, 'penalty': 'l1', 'solver': 'liblinear'}

best_params = {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'lbfgs'}

# %% [markdown]
# ## Load Dataframes

# %%
# Filter Columns
filter = ['session_time', 'gender', 'age_gen', 'day', 'timeofday', 'first_outcome',
        'first_wager','first_p/b', 'last_outcome', 'last_wager', 'last_p/b',
        'beginning_amt', 'ending_amt', 'ending_balance', 'ave_slotdenom', 
        'std_slotdenom', 'min_slotdenom', 'max_slotdenom', 'ave_theo_payback',
        'min_theo_payback', 'max_theo_payback', 'ave_wageramt', 'std_wageramt',
        'min_wager', 'max_wager', 'ave_p/b', 'std_p/b', 'max_p/b', 'max_profit', 'depletion_slope', 
        '#inc_slotdenom', '#dec_slotdenom', '#inc_maxbet', '#dec_maxbet',
        'w/min', 'l/min', 'nh/min', 'd/min', '2ws_profit', '2ws_wgramt','2ws/min', 
        '3ws_profit', '3ws_wgramt', '3ws/min', '4ws_profit', '4ws_wgramt', '4ws/min', 
        'w/g', 'l/g', 'nh/g', 'd/g', 'ave_time_per_gamble',
        'min_time_per_gamble', 'machines_changes', 'unique_machines', 'classification']

# %% [markdown]
# ## June

# %%
training = ['6_October', '3_July', '4_August', '5_September']
testing = ['2_June']

june_test, jn_y_test, jn_y_pred, jn_x_test , jn_df, jn_classifier, ct = cf.run_lr_combine(months, data_path, filter, training, testing, best_params)

print(june_test.to_latex(index=False))
# Out:
# [[231   8]
#  [ 15  13]]
# \begin{tabular}{lrrrr}
# \toprule
# Test Month &  Accuracy &  Precision &  Recall &  F1 Score \\
# \midrule
#       June &     0.914 &      0.779 &   0.715 &     0.742 \\
# \bottomrule
# \end{tabular}
# /var/folders/vp/1skwx2kd29s4fxnxx7tt9r6w0000gn/T/ipykernel_1613/141203780.py:6: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(june_test.to_latex(index=False))

# %%
cf.plot_cap_curve(jn_y_test, jn_y_pred)

# %%
june_features = cf.feature_importance_lr(jn_df, jn_classifier, ct)

# %%
print(june_features.head(5))
# Out:
#        Feature  Coefficient  Abs_Coefficient
# 44     std_p/b    -6.994146         6.994146
# 45     max_p/b     6.133825         6.133825
# 59  3ws_profit     5.226329         5.226329
# 57  2ws_wgramt     5.015981         5.015981
# 46  max_profit    -3.060816         3.060816

# %% [markdown]
# ## July

# %%
training = ['2_June', '6_October', '4_August', '5_September']
testing = ['3_July']
july_test, jl_y_test, jl_y_pred, jl_x_test , jl_df, jl_classifier, ct = cf.run_lr_combine(months, data_path, filter, training, testing, best_params)

print(july_test.to_latex(index=False))
# Out:
# [[10525  1499]
#  [  288  1166]]
# \begin{tabular}{lrrrr}
# \toprule
# Test Month &  Accuracy &  Precision &  Recall &  F1 Score \\
# \midrule
#       July &     0.867 &      0.705 &   0.839 &     0.744 \\
# \bottomrule
# \end{tabular}
# /var/folders/vp/1skwx2kd29s4fxnxx7tt9r6w0000gn/T/ipykernel_1613/3308883200.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(july_test.to_latex(index=False))

# %%
cf.plot_cap_curve(jl_y_test, jl_y_pred)

# %%
july_features = cf.feature_importance_lr(jl_df, jl_classifier, ct)

# %%
print(july_features.head(5))
# Out:
#        Feature  Coefficient  Abs_Coefficient
# 44     std_p/b    -7.634878         7.634878
# 45     max_p/b     6.774230         6.774230
# 46  max_profit    -3.660521         3.660521
# 57  2ws_wgramt     3.595462         3.595462
# 56  2ws_profit     2.987882         2.987882

# %% [markdown]
# ## August

# %%
training = ['2_June', '3_July', '6_October', '5_September']
testing = ['4_August']

august_test, aug_y_test, aug_y_pred, aug_x_test , aug_df, aug_classifier, ct = cf.run_lr_combine(months, data_path, filter, training, testing, best_params)

print(august_test.to_latex(index=False))
# Out:
# [[9484 1222]
#  [ 277 1017]]
# \begin{tabular}{lrrrr}
# \toprule
# Test Month &  Accuracy &  Precision &  Recall &  F1 Score \\
# \midrule
#     August &     0.875 &      0.713 &   0.836 &     0.751 \\
# \bottomrule
# \end{tabular}
# /var/folders/vp/1skwx2kd29s4fxnxx7tt9r6w0000gn/T/ipykernel_1613/3059816320.py:6: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(august_test.to_latex(index=False))

# %%
cf.plot_cap_curve(aug_y_test, aug_y_pred)

# %%
august_features = cf.feature_importance_lr(aug_df, aug_classifier, ct)

# %%
print(august_features.head(5))
# Out:
#        Feature  Coefficient  Abs_Coefficient
# 44     std_p/b    -7.844921         7.844921
# 45     max_p/b     6.560355         6.560355
# 57  2ws_wgramt     6.266030         6.266030
# 59  3ws_profit     5.000086         5.000086
# 52       w/min     3.980697         3.980697

# %% [markdown]
# ## September

# %%
training = ['2_June', '3_July', '4_August', '6_October']
testing = ['5_September']
september_test, sep_y_test, sep_y_pred, sep_x_test , sep_df, sep_classifier, ct = cf.run_lr_combine(months, data_path, filter, training, testing, best_params)

print(september_test.to_latex(index=False))
# Out:
# [[8765 1139]
#  [ 203 1004]]
# \begin{tabular}{lrrrr}
# \toprule
# Test Month &  Accuracy &  Precision &  Recall &  F1 Score \\
# \midrule
#  September &     0.879 &      0.723 &   0.858 &     0.764 \\
# \bottomrule
# \end{tabular}
# /var/folders/vp/1skwx2kd29s4fxnxx7tt9r6w0000gn/T/ipykernel_1613/905690229.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(september_test.to_latex(index=False))

# %%
cf.plot_cap_curve(sep_y_test, sep_y_pred)

# %%
september_features = cf.feature_importance_lr(sep_df, sep_classifier, ct)

# %%
print(september_features.head(5))
# Out:
#        Feature  Coefficient  Abs_Coefficient
# 59  3ws_profit     7.327089         7.327089
# 44     std_p/b    -6.335706         6.335706
# 56  2ws_profit     5.829746         5.829746
# 45     max_p/b     5.556930         5.556930
# 57  2ws_wgramt     3.943444         3.943444

# %% [markdown]
# ## October

# %%
training = ['2_June', '3_July', '4_August', '5_September']
testing = ['6_October']
october_test, oct_y_test, oct_y_pred, oct_x_test , oct_df, oct_classifier, ct = cf.run_lr_combine(months, data_path, filter, training, testing, best_params)

print(october_test.to_latex(index=False))
# Out:
# [[4406  533]
#  [ 132  453]]
# \begin{tabular}{lrrrr}
# \toprule
# Test Month &  Accuracy &  Precision &  Recall &  F1 Score \\
# \midrule
#    October &      0.88 &      0.715 &   0.833 &     0.753 \\
# \bottomrule
# \end{tabular}
# /var/folders/vp/1skwx2kd29s4fxnxx7tt9r6w0000gn/T/ipykernel_1613/834593762.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(october_test.to_latex(index=False))

# %%
cf.plot_cap_curve(oct_y_test, oct_y_pred)

# %%
october_features = cf.feature_importance_lr(oct_df, oct_classifier, ct)

# %%
print(october_features.head(5))
# Out:
#        Feature  Coefficient  Abs_Coefficient
# 59  3ws_profit     6.820041         6.820041
# 44     std_p/b    -6.145269         6.145269
# 45     max_p/b     5.322557         5.322557
# 57  2ws_wgramt     5.242518         5.242518
# 52       w/min     3.166715         3.166715

# %% [markdown]
# ## Save Dataframes

# %%
os.chdir('/Users/mau/Library/CloudStorage/Dropbox/Mac/Documents/Dissertation/Chapter 2/Entire_Data/Feauture Importance/Overall/LR')
june_features.to_csv('june_features.csv')
july_features.to_csv('july_features.csv')
august_features.to_csv('august_features.csv')
september_features.to_csv('september_features.csv')
october_features.to_csv('october_features.csv')
