# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Data Preprocessing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier


# Set working directory
month_file = '4_August'
# Set working directory
os.chdir("/Users/mau/Library/CloudStorage/Dropbox/Mac/Documents/Dissertation/Chapter 2/Entire_Data/By month/"+month_file+"/Ending Balances/Per_Player")

# %% [markdown]
# ## Load Dataframes

# %% [markdown]
# ### 1 MIN

# %%
filter = ['session_time', 'gender',  'sim_play', 'age_gen', 'first_outcome',
        'first_wager','first_p/b', 'last_outcome', 'last_wager', 'last_p/b',
        'beginning_amt', 'ending_amt', 'ending_balance', 'ave_slotdenom', 
        'std_slotdenom', 'min_slotdenom', 'max_slotdenom', 'ave_theo_payback',
        'min_theo_payback', 'max_theo_payback', 'ave_wageramt', 'std_wageramt',
        'min_wager', 'max_wager', 'ave_p/b', 'std_p/b', 'max_p/b', 'max_profit', 'depletion_slope', 
        '#inc_slotdenom', '#dec_slotdenom', '#inc_maxbet', '#dec_maxbet', 
        '#W', '#L', '#NH', '#D','w/g', 'l/g', 'nh/g', 'd/g', '#2ws', '2ws_profit', '2ws_wgramt', '#3ws',
        '3ws_profit', '3ws_wgramt', '#4ws', '4ws_profit', '4ws_wgramt','ave_time_per_gamble', 
        'min_time_per_gamble', 'max_time_per_gamble',
        'machines_changes', 'unique_machines',  'ave_time_per_machine', 'percentile']

# Columns NOT INCLUDED
# 'playerkey', 'rank', 'age_range', '#W', '#L', '#NH', '#D','total_duration', 'total_gambles'

# Load dataset
dataset = pd.read_parquet('df_1min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[356 131]
#  [182 314]]
# Accuracy:  0.681586978636826
# Precision:  0.7056179775280899
# Recall:  0.6330645161290323
# F1 Score:  0.6673751328374069
# True Positive (B20):  356
# True Negative (T20):  314
# False Positive:  131
# False Negative:  182

# %% [markdown]
# ### 2 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_2min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[376 111]
#  [157 339]]
# Accuracy:  0.7273652085452695
# Precision:  0.7533333333333333
# Recall:  0.6834677419354839
# F1 Score:  0.7167019027484144
# True Positive (B20):  376
# True Negative (T20):  339
# False Positive:  111
# False Negative:  157

# %% [markdown]
# ### 3 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_3min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[405  82]
#  [146 350]]
# Accuracy:  0.768056968463886
# Precision:  0.8101851851851852
# Recall:  0.7056451612903226
# F1 Score:  0.7543103448275862
# True Positive (B20):  405
# True Negative (T20):  350
# False Positive:  82
# False Negative:  146

# %% [markdown]
# ### 4 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_4min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[415  72]
#  [144 352]]
# Accuracy:  0.780264496439471
# Precision:  0.8301886792452831
# Recall:  0.7096774193548387
# F1 Score:  0.7652173913043478
# True Positive (B20):  415
# True Negative (T20):  352
# False Positive:  72
# False Negative:  144

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(classifier, X_train, y_train, n_repeats=10, random_state=42)

# Get feature importances and feature names
importances = result.importances_mean
feature_names = ct.get_feature_names_out()

# Sort feature importances
feature_importance = list(zip(feature_names, importances))
feature_importance.sort(key=lambda x: x[1], reverse=True)

# Print feature importances
for feature, importance in feature_importance:
    print(f"{feature}: {importance}")
# Out:
# remainder__x54: 0.06615776081424936
# remainder__x10: 0.046768447837150104
# remainder__x33: 0.04300254452926207
# encoder__x2_Millenials: 0.03503816793893129
# remainder__x26: 0.03340966921119589
# remainder__x32: 0.03249363867684477
# remainder__x49: 0.023867684478371474
# remainder__x9: 0.01923664122137402
# remainder__x25: 0.019134860050890556
# remainder__x50: 0.017022900763358752
# remainder__x34: 0.01577608142493636
# remainder__x16: 0.013486005089058516
# remainder__x18: 0.012748091603053402
# remainder__x11: 0.012697201017811665
# remainder__x23: 0.01254452926208648
# remainder__x24: 0.012493638676844753
# remainder__x27: 0.012391857506361303
# remainder__x36: 0.012162849872773518
# remainder__x17: 0.011399491094147573
# remainder__x37: 0.010229007633587773
# encoder__x2_Baby Boomers: 0.010101781170483447
# remainder__x51: 0.009033078880407108
# remainder__x53: 0.008651399491094136
# remainder__x19: 0.007735368956742983
# remainder__x21: 0.007150127226463077
# remainder__x38: 0.005292620865139941
# remainder__x39: 0.005267175572519045
# remainder__x7: 0.0047837150127226225
# remainder__x8: 0.0046055979643765625
# remainder__x4: 0.004503816793893112
# remainder__x52: 0.004452926208651375
# remainder__x35: 0.004351145038167914
# remainder__x12: 0.004249363867684463
# remainder__x20: 0.003867684478371447
# remainder__x40: 0.0033078880407124366
# remainder__x5: 0.002900763358778602
# remainder__x15: 0.0027226463104325417
# remainder__x22: 0.0026717557251908276
# encoder__x2_Gen X: 0.0018066157760814106
# remainder__x42: 0.0017302798982188005
# remainder__x0: 0.0014758269720101524
# encoder__x2_Silent: 0.0012977099236641033
# encoder__x3_near-hit: 0.0012213740458015044
# encoder__x3_gain: 0.0010941475826971915
# remainder__x30: 0.0010687022900763288
# encoder__x6_loss: 0.001043256997455444
# remainder__x41: 0.0010178117048345926
# remainder__x13: 0.0008905852417302462
# remainder__x14: 0.0007633587786259222
# encoder__x6_gain: 0.0006361323155215981
# encoder__x3_loss: 0.0005089058524172518
# encoder__x3_draw: 0.00043256997455466407
# remainder__x45: 0.00043256997455466407
# encoder__x6_near-hit: 0.0003053435114503511
# encoder__x2_Gen Z: 0.0002544529262086259
# remainder__x29: 0.00022900763358776332
# remainder__x31: 0.00017811704834603815
# remainder__x43: 2.544529262086259e-05
# encoder__x6_draw: 0.0
# remainder__x1: 0.0
# remainder__x28: 0.0
# remainder__x44: 0.0
# remainder__x46: 0.0
# remainder__x47: 0.0
# remainder__x48: 0.0

# %% [markdown]
# ### 5 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_5min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[428  59]
#  [133 363]]
# Accuracy:  0.8046795523906409
# Precision:  0.8601895734597157
# Recall:  0.7318548387096774
# F1 Score:  0.7908496732026143
# True Positive (B20):  428
# True Negative (T20):  363
# False Positive:  59
# False Negative:  133

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(classifier, X_train, y_train, n_repeats=10, random_state=42)

# Get feature importances and feature names
importances = result.importances_mean
feature_names = ct.get_feature_names_out()

# Sort feature importances
feature_importance = list(zip(feature_names, importances))
feature_importance.sort(key=lambda x: x[1], reverse=True)

# Print feature importances
for feature, importance in feature_importance:
    print(f"{feature}: {importance}")
# Out:
# remainder__x54: 0.08506361323155219
# remainder__x33: 0.07763358778625959
# remainder__x26: 0.03338422391857511
# remainder__x10: 0.030508905852417355
# remainder__x9: 0.025318066157760843
# encoder__x2_Millenials: 0.02384223918575068
# remainder__x49: 0.023002544529262148
# remainder__x25: 0.02089058524173033
# remainder__x32: 0.01796437659033081
# remainder__x51: 0.013842239185750671
# remainder__x23: 0.013791348600508947
# remainder__x34: 0.013358778625954238
# remainder__x24: 0.010916030534351173
# remainder__x27: 0.009389312977099284
# remainder__x36: 0.009312977099236674
# remainder__x50: 0.007480916030534401
# remainder__x53: 0.007404580152671802
# remainder__x37: 0.007379134860050929
# remainder__x16: 0.00712468193384227
# remainder__x19: 0.006819338422391907
# remainder__x17: 0.006361323155216314
# remainder__x4: 0.006055979643765941
# remainder__x11: 0.005801526717557293
# remainder__x20: 0.00577608142493643
# encoder__x2_Baby Boomers: 0.005725190839694671
# remainder__x18: 0.005318066157760859
# remainder__x35: 0.005114503816793914
# remainder__x21: 0.00498727735368959
# remainder__x22: 0.0047582697201018044
# encoder__x2_Gen X: 0.004732824427480941
# remainder__x38: 0.004631043256997513
# remainder__x12: 0.00463104325699748
# remainder__x7: 0.004045801526717585
# remainder__x14: 0.004045801526717585
# remainder__x39: 0.0033078880407125034
# remainder__x5: 0.0031806615776081904
# remainder__x0: 0.0025190839694656853
# remainder__x40: 0.002340966921119625
# remainder__x52: 0.001933842239185779
# remainder__x15: 0.0017048346055980046
# remainder__x8: 0.001526717557251933
# remainder__x42: 0.0012977099236641699
# remainder__x41: 0.0010941475826972357
# encoder__x6_loss: 0.0007633587786259888
# encoder__x3_gain: 0.0007124681933842636
# encoder__x6_near-hit: 0.0005089058524173629
# encoder__x6_gain: 0.0004834605597965003
# encoder__x3_loss: 0.00045801526717559327
# encoder__x2_Gen Z: 0.0004071246819339014
# remainder__x30: 0.0003816793893130499
# remainder__x31: 0.0003816793893130388
# encoder__x3_near-hit: 0.0003053435114504399
# encoder__x2_Silent: 0.00025445292620872583
# encoder__x3_draw: 0.00022900763358786326
# remainder__x13: 0.00020356234096697846
# remainder__x45: 0.00010178117048349477
# remainder__x44: 5.089058524174739e-05
# remainder__x48: 2.5445292620873693e-05
# remainder__x1: 0.0
# remainder__x28: 0.0
# remainder__x43: 0.0
# remainder__x46: 0.0
# remainder__x47: 0.0
# encoder__x6_draw: -2.544529262086259e-05
# remainder__x29: -2.544529262086259e-05

# %% [markdown]
# ### 10 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_10min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)


y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[463  24]
#  [ 96 400]]
# Accuracy:  0.8779247202441506
# Precision:  0.9433962264150944
# Recall:  0.8064516129032258
# F1 Score:  0.8695652173913043
# True Positive (B20):  463
# True Negative (T20):  400
# False Positive:  24
# False Negative:  96

# %% [markdown]
# ### 15 MIN

# %%
# Load dataset
dataset = pd.read_parquet('df_15min.parquet', columns=filter)

# Keep only session_time 1
dataset = dataset[dataset['session_time'] == 1]
# Drop age_range and playerkey
dataset = dataset.drop(['session_time'], axis=1)

# Convert ave_time_per_machine to seconds
dataset['ave_time_per_machine'] = dataset['ave_time_per_machine'].dt.total_seconds()

# # Seperate dependent and independent variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Econde gender column (Binary)
le = LabelEncoder()

# Binary Encode gender and simplay
X[:, 0] = le.fit_transform(X[:, 0])
X[:, 1] = le.fit_transform(X[:, 1])

# # Encode age_generartion, first_outoce, last_outcome columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [2, 3, 6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

sc = StandardScaler()

# Scale all columns except the encoded ones
X_train[:, 14:] = sc.fit_transform(X_train[:, 14:])
X_test[:, 14:] = sc.transform(X_test[:, 14:])

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)


y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('Precision: ', precision_score(y_test, y_pred))
print('Recall: ', recall_score(y_test, y_pred))
print('F1 Score: ', f1_score(y_test, y_pred))

# Interpretation of confusion matrix
print('True Positive (B20): ', cm[0][0])
print('True Negative (T20): ', cm[1][1])
print('False Positive: ', cm[0][1])
print('False Negative: ', cm[1][0])
# Out:
# [[475  12]
#  [ 84 412]]
# Accuracy:  0.9023397761953205
# Precision:  0.9716981132075472
# Recall:  0.8306451612903226
# F1 Score:  0.8956521739130434
# True Positive (B20):  475
# True Negative (T20):  412
# False Positive:  12
# False Negative:  84
